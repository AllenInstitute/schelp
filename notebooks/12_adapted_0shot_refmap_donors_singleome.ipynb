# %% [markdown]
# - Here evaluate 0-shot reference mapping on an internal (Allen Institute) human brain dataset.
# - We provide a roughly balanced dataset as the reference (test donors are completely removed)
# - The query dataset is created from high-supertype entropy group of donors. (see `11_explore_donor_splits`).

# %%
from pathlib import Path
import warnings
import subprocess
import sys

import numpy as np
import pandas as pd
from scipy.stats import mode
import scanpy as sc
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
from tqdm import tqdm
from rich import print as rprint
from schelp.utils.config import load_config
from schelp.utils.data import donor_split, make_donor_splits_dataset

import matplotlib.pyplot as plt
import seaborn as sns

import torchtext

torchtext.disable_torchtext_deprecation_warning()

import scgpt as scg
import faiss


custom_params = {"axes.spines.right": False, "axes.spines.top": False}
sns.set_theme(style="ticks", font_scale=0.8, rc=custom_params)
# %config InlineBackend.figure_format='retina'
# Out:
# /allen/programs/celltypes/workgroups/mousecelltypes/Rohan/code/scgpt/scGPT/scgpt/model/model.py:21: UserWarning: flash_attn is not installed
#   warnings.warn("flash_attn is not installed")
# /allen/programs/celltypes/workgroups/mousecelltypes/Rohan/code/scgpt/scGPT/scgpt/model/multiomic_model.py:19: UserWarning: flash_attn is not installed
#   warnings.warn("flash_attn is not installed")

# %%
paths = load_config(dataset_key="init")
subprocess.run(["tree", "-L", "1", paths["data"]])
subprocess.run(["tree", "-L", "1", paths["pretrained_models"]])
# Out:
# /allen/programs/celltypes/workgroups/mousecelltypes/Rohan/code/scgpt/datasets
# ├── COVID-19-splitted
# ├── Human-Brain
# ├── Lung-Kim-splitted
# ├── ms
# └── results
#
# 6 directories, 0 files
# /allen/programs/celltypes/workgroups/mousecelltypes/Rohan/code/scgpt/pretrained_models
# ├── scGPT_CP
# ├── scGPT_brain
# └── scGPT_human
#
# 4 directories, 0 files
# CompletedProcess(args=['tree', '-L', '1', PosixPath('/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/code/scgpt/pretrained_models')], returncode=0)

# %% [markdown]
# We set the columns storing gene name columns, batch key and cell type key.

# %%
from schelp.utils.config import load_config
from rich import print as rprint
import pandas as pd
import anndata as ad
from schelp.utils.data import add_scgpt_data_columns

# %%
paths = load_config(dataset_key="init")
adata_train = ad.read_h5ad(paths["data"] / "Human-Brain/v1_donor_split_train.h5ad")
adata_test = ad.read_h5ad(paths["data"] / "Human-Brain/v1_donor_split_test.h5ad")

# %%
adata_train, num_types, id2type, celltypes = add_scgpt_data_columns(adata_train)
adata_test, _, _, celltypes_test = add_scgpt_data_columns(adata_test)

# %%
cell_type_key = "celltype"
gene_col = "gene_name"

display(adata_train.var[gene_col].to_frame().head(3))
display(adata_train.obs[cell_type_key].to_frame().head(3))
# Out:
#        gene_name
# SAMD11    SAMD11
# HES4        HES4
# MXRA8      MXRA8
#                                                celltype
# exp_component_name
# CATCAAGTCGGATACT-L8TX_210729_01_G12-1153814338  Oligo_4
# AAGCCATGTGATATAG-LKTX_191204_01_F01-1156636535  Oligo_4
# TCGATTTGTCGTGATT-L8TX_210715_01_D05-1153814295  Oligo_4

# %% [markdown]
# Embed the reference dataset

# %%
model_dir = Path(str(paths["pretrained_models"] / "scGPT_brain"))
ref_embed_adata = scg.tasks.embed_data(
    adata_train,
    model_dir,
    gene_col=gene_col,
    batch_size=128,
)
# Out:
# scGPT - INFO - match 3388/4000 genes in vocabulary of size 60697.
# /allen/programs/celltypes/workgroups/mousecelltypes/Rohan/code/scgpt/scGPT/scgpt/model/model.py:77: UserWarning: flash-attn is not installed, using pytorch transformer instead. Set use_fast_transformer=False to avoid this warning. Installing flash-attn is highly recommended.
#   warnings.warn(
# Embedding cells: 100%|██████████| 929/929 [03:21<00:00,  5.46it/s]Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 300, in _run_finalizers
#     finalizer()
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 300, in _run_finalizers
#     finalizer()
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 300, in _run_finalizers
#     finalizer()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 300, in _run_finalizers
#     finalizer()
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 300, in _run_finalizers
#     finalizer()
# Traceback (most recent call last):
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 300, in _run_finalizers
#     finalizer()
# Traceback (most recent call last):
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 224, in __call__
#     res = self._callback(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 224, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 300, in _run_finalizers
#     finalizer()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 300, in _run_finalizers
#     finalizer()
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 224, in __call__
#     res = self._callback(*self._args, **self._kwargs)
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 300, in _run_finalizers
#     finalizer()
# Traceback (most recent call last):
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 300, in _run_finalizers
#     finalizer()
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 300, in _run_finalizers
#     finalizer()
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 300, in _run_finalizers
#     finalizer()
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 224, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 300, in _run_finalizers
#     finalizer()
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 300, in _run_finalizers
#     finalizer()
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 300, in _run_finalizers
#     finalizer()
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 300, in _run_finalizers
#     finalizer()
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 300, in _run_finalizers
#     finalizer()
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 300, in _run_finalizers
#     finalizer()
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 300, in _run_finalizers
#     finalizer()
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 300, in _run_finalizers
#     finalizer()
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 224, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 300, in _run_finalizers
#     finalizer()
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 300, in _run_finalizers
#     finalizer()
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 300, in _run_finalizers
#     finalizer()
# Traceback (most recent call last):
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 224, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 300, in _run_finalizers
#     finalizer()
# Traceback (most recent call last):
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 133, in _remove_temp_dir
#     rmtree(tempdir)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 133, in _remove_temp_dir
#     rmtree(tempdir)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 300, in _run_finalizers
#     finalizer()
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 300, in _run_finalizers
#     finalizer()
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 300, in _run_finalizers
#     finalizer()
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 224, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 300, in _run_finalizers
#     finalizer()
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 224, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 300, in _run_finalizers
#     finalizer()
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 300, in _run_finalizers
#     finalizer()
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 133, in _remove_temp_dir
#     rmtree(tempdir)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 224, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 224, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 224, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 224, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 133, in _remove_temp_dir
#     rmtree(tempdir)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 224, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 224, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 224, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 224, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 224, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 224, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 224, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 224, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 133, in _remove_temp_dir
#     rmtree(tempdir)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 224, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 224, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 133, in _remove_temp_dir
#     rmtree(tempdir)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 224, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 300, in _run_finalizers
#     finalizer()
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 224, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 734, in rmtree
#     _rmtree_safe_fd(fd, path, onerror)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 300, in _run_finalizers
#     finalizer()
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 734, in rmtree
#     _rmtree_safe_fd(fd, path, onerror)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 224, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 224, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 133, in _remove_temp_dir
#     rmtree(tempdir)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 224, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 224, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 133, in _remove_temp_dir
#     rmtree(tempdir)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 224, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 734, in rmtree
#     _rmtree_safe_fd(fd, path, onerror)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 133, in _remove_temp_dir
#     rmtree(tempdir)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 224, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 133, in _remove_temp_dir
#     rmtree(tempdir)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 133, in _remove_temp_dir
#     rmtree(tempdir)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 133, in _remove_temp_dir
#     rmtree(tempdir)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 734, in rmtree
#     _rmtree_safe_fd(fd, path, onerror)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 133, in _remove_temp_dir
#     rmtree(tempdir)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 133, in _remove_temp_dir
#     rmtree(tempdir)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 133, in _remove_temp_dir
#     rmtree(tempdir)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 133, in _remove_temp_dir
#     rmtree(tempdir)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 133, in _remove_temp_dir
#     rmtree(tempdir)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 133, in _remove_temp_dir
#     rmtree(tempdir)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 133, in _remove_temp_dir
#     rmtree(tempdir)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 133, in _remove_temp_dir
#     rmtree(tempdir)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 734, in rmtree
#     _rmtree_safe_fd(fd, path, onerror)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 133, in _remove_temp_dir
#     rmtree(tempdir)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 133, in _remove_temp_dir
#     rmtree(tempdir)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 734, in rmtree
#     _rmtree_safe_fd(fd, path, onerror)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 133, in _remove_temp_dir
#     rmtree(tempdir)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 133, in _remove_temp_dir
#     rmtree(tempdir)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 690, in _rmtree_safe_fd
#     onerror(os.unlink, fullname, sys.exc_info())
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 224, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 224, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 690, in _rmtree_safe_fd
#     onerror(os.unlink, fullname, sys.exc_info())
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 133, in _remove_temp_dir
#     rmtree(tempdir)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 734, in rmtree
#     _rmtree_safe_fd(fd, path, onerror)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 133, in _remove_temp_dir
#     rmtree(tempdir)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 133, in _remove_temp_dir
#     rmtree(tempdir)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 133, in _remove_temp_dir
#     rmtree(tempdir)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 734, in rmtree
#     _rmtree_safe_fd(fd, path, onerror)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 133, in _remove_temp_dir
#     rmtree(tempdir)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 734, in rmtree
#     _rmtree_safe_fd(fd, path, onerror)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 690, in _rmtree_safe_fd
#     onerror(os.unlink, fullname, sys.exc_info())
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 734, in rmtree
#     _rmtree_safe_fd(fd, path, onerror)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 133, in _remove_temp_dir
#     rmtree(tempdir)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 734, in rmtree
#     _rmtree_safe_fd(fd, path, onerror)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 690, in _rmtree_safe_fd
#     onerror(os.unlink, fullname, sys.exc_info())
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 734, in rmtree
#     _rmtree_safe_fd(fd, path, onerror)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 734, in rmtree
#     _rmtree_safe_fd(fd, path, onerror)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 734, in rmtree
#     _rmtree_safe_fd(fd, path, onerror)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 734, in rmtree
#     _rmtree_safe_fd(fd, path, onerror)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 734, in rmtree
#     _rmtree_safe_fd(fd, path, onerror)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 734, in rmtree
#     _rmtree_safe_fd(fd, path, onerror)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 734, in rmtree
#     _rmtree_safe_fd(fd, path, onerror)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 690, in _rmtree_safe_fd
#     onerror(os.unlink, fullname, sys.exc_info())
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 734, in rmtree
#     _rmtree_safe_fd(fd, path, onerror)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 734, in rmtree
#     _rmtree_safe_fd(fd, path, onerror)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 734, in rmtree
#     _rmtree_safe_fd(fd, path, onerror)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 734, in rmtree
#     _rmtree_safe_fd(fd, path, onerror)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 690, in _rmtree_safe_fd
#     onerror(os.unlink, fullname, sys.exc_info())
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 734, in rmtree
#     _rmtree_safe_fd(fd, path, onerror)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 734, in rmtree
#     _rmtree_safe_fd(fd, path, onerror)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 133, in _remove_temp_dir
#     rmtree(tempdir)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 688, in _rmtree_safe_fd
#     os.unlink(entry.name, dir_fd=topfd)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 133, in _remove_temp_dir
#     rmtree(tempdir)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 688, in _rmtree_safe_fd
#     os.unlink(entry.name, dir_fd=topfd)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 734, in rmtree
#     _rmtree_safe_fd(fd, path, onerror)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 690, in _rmtree_safe_fd
#     onerror(os.unlink, fullname, sys.exc_info())
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 734, in rmtree
#     _rmtree_safe_fd(fd, path, onerror)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 734, in rmtree
#     _rmtree_safe_fd(fd, path, onerror)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 690, in _rmtree_safe_fd
#     onerror(os.unlink, fullname, sys.exc_info())
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 734, in rmtree
#     _rmtree_safe_fd(fd, path, onerror)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 734, in rmtree
#     _rmtree_safe_fd(fd, path, onerror)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 690, in _rmtree_safe_fd
#     onerror(os.unlink, fullname, sys.exc_info())
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 688, in _rmtree_safe_fd
#     os.unlink(entry.name, dir_fd=topfd)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 690, in _rmtree_safe_fd
#     onerror(os.unlink, fullname, sys.exc_info())
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 734, in rmtree
#     _rmtree_safe_fd(fd, path, onerror)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 690, in _rmtree_safe_fd
#     onerror(os.unlink, fullname, sys.exc_info())
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 688, in _rmtree_safe_fd
#     os.unlink(entry.name, dir_fd=topfd)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 690, in _rmtree_safe_fd
#     onerror(os.unlink, fullname, sys.exc_info())
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 690, in _rmtree_safe_fd
#     onerror(os.unlink, fullname, sys.exc_info())
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 690, in _rmtree_safe_fd
#     onerror(os.unlink, fullname, sys.exc_info())
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 690, in _rmtree_safe_fd
#     onerror(os.unlink, fullname, sys.exc_info())
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 690, in _rmtree_safe_fd
#     onerror(os.unlink, fullname, sys.exc_info())
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 690, in _rmtree_safe_fd
#     onerror(os.unlink, fullname, sys.exc_info())
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 690, in _rmtree_safe_fd
#     onerror(os.unlink, fullname, sys.exc_info())
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 688, in _rmtree_safe_fd
#     os.unlink(entry.name, dir_fd=topfd)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 690, in _rmtree_safe_fd
#     onerror(os.unlink, fullname, sys.exc_info())
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 690, in _rmtree_safe_fd
#     onerror(os.unlink, fullname, sys.exc_info())
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 688, in _rmtree_safe_fd
#     os.unlink(entry.name, dir_fd=topfd)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 690, in _rmtree_safe_fd
#     onerror(os.unlink, fullname, sys.exc_info())
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 690, in _rmtree_safe_fd
#     onerror(os.unlink, fullname, sys.exc_info())
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 690, in _rmtree_safe_fd
#     onerror(os.unlink, fullname, sys.exc_info())
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 690, in _rmtree_safe_fd
#     onerror(os.unlink, fullname, sys.exc_info())
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 734, in rmtree
#     _rmtree_safe_fd(fd, path, onerror)
# OSError: [Errno 16] Device or resource busy: '.nfs00000005a7c206a400000db8'
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 734, in rmtree
#     _rmtree_safe_fd(fd, path, onerror)
# OSError: [Errno 16] Device or resource busy: '.nfs00000005a77e97f500000dcc'
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 690, in _rmtree_safe_fd
#     onerror(os.unlink, fullname, sys.exc_info())
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 688, in _rmtree_safe_fd
#     os.unlink(entry.name, dir_fd=topfd)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 690, in _rmtree_safe_fd
#     onerror(os.unlink, fullname, sys.exc_info())
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 690, in _rmtree_safe_fd
#     onerror(os.unlink, fullname, sys.exc_info())
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 688, in _rmtree_safe_fd
#     os.unlink(entry.name, dir_fd=topfd)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 690, in _rmtree_safe_fd
#     onerror(os.unlink, fullname, sys.exc_info())
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 690, in _rmtree_safe_fd
#     onerror(os.unlink, fullname, sys.exc_info())
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 688, in _rmtree_safe_fd
#     os.unlink(entry.name, dir_fd=topfd)
# OSError: [Errno 16] Device or resource busy: '.nfs00000005a714760800000db5'
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 688, in _rmtree_safe_fd
#     os.unlink(entry.name, dir_fd=topfd)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 688, in _rmtree_safe_fd
#     os.unlink(entry.name, dir_fd=topfd)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 690, in _rmtree_safe_fd
#     onerror(os.unlink, fullname, sys.exc_info())
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 688, in _rmtree_safe_fd
#     os.unlink(entry.name, dir_fd=topfd)
# OSError: [Errno 16] Device or resource busy: '.nfs00000005a747408400000dbf'
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 688, in _rmtree_safe_fd
#     os.unlink(entry.name, dir_fd=topfd)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 688, in _rmtree_safe_fd
#     os.unlink(entry.name, dir_fd=topfd)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 688, in _rmtree_safe_fd
#     os.unlink(entry.name, dir_fd=topfd)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 688, in _rmtree_safe_fd
#     os.unlink(entry.name, dir_fd=topfd)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 688, in _rmtree_safe_fd
#     os.unlink(entry.name, dir_fd=topfd)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 688, in _rmtree_safe_fd
#     os.unlink(entry.name, dir_fd=topfd)
# OSError: [Errno 16] Device or resource busy: '.nfs00000005a7c206a600000dbb'
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 688, in _rmtree_safe_fd
#     os.unlink(entry.name, dir_fd=topfd)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 688, in _rmtree_safe_fd
#     os.unlink(entry.name, dir_fd=topfd)
# OSError: [Errno 16] Device or resource busy: '.nfs00000005a6625eb000000db7'
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 688, in _rmtree_safe_fd
#     os.unlink(entry.name, dir_fd=topfd)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 688, in _rmtree_safe_fd
#     os.unlink(entry.name, dir_fd=topfd)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 688, in _rmtree_safe_fd
#     os.unlink(entry.name, dir_fd=topfd)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 688, in _rmtree_safe_fd
#     os.unlink(entry.name, dir_fd=topfd)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 690, in _rmtree_safe_fd
#     onerror(os.unlink, fullname, sys.exc_info())
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 690, in _rmtree_safe_fd
#     onerror(os.unlink, fullname, sys.exc_info())
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 688, in _rmtree_safe_fd
#     os.unlink(entry.name, dir_fd=topfd)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 688, in _rmtree_safe_fd
#     os.unlink(entry.name, dir_fd=topfd)
# OSError: [Errno 16] Device or resource busy: '.nfs00000005a797148900000dc2'
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 688, in _rmtree_safe_fd
#     os.unlink(entry.name, dir_fd=topfd)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 688, in _rmtree_safe_fd
#     os.unlink(entry.name, dir_fd=topfd)
# OSError: [Errno 16] Device or resource busy: '.nfs00000005a77b279a00000db2'
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 688, in _rmtree_safe_fd
#     os.unlink(entry.name, dir_fd=topfd)
# OSError: [Errno 16] Device or resource busy: '.nfs00000005a65dbb4600000dbc'
# OSError: [Errno 16] Device or resource busy: '.nfs00000005a733e38700000dc0'
# OSError: [Errno 16] Device or resource busy: '.nfs00000005a7b266b900000dcf'
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 688, in _rmtree_safe_fd
#     os.unlink(entry.name, dir_fd=topfd)
# OSError: [Errno 16] Device or resource busy: '.nfs00000005a797148800000db3'
# OSError: [Errno 16] Device or resource busy: '.nfs00000005a72f292d00000db9'
# OSError: [Errno 16] Device or resource busy: '.nfs00000005a77c21b000000db6'
# OSError: [Errno 16] Device or resource busy: '.nfs00000005a65dbb4800000dbe'
# OSError: [Errno 16] Device or resource busy: '.nfs00000005a760530e00000db4'
# OSError: [Errno 16] Device or resource busy: '.nfs00000005a630609c00000dc3'
# OSError: [Errno 16] Device or resource busy: '.nfs00000005a71fcc0800000dcd'
# OSError: [Errno 16] Device or resource busy: '.nfs00000005a6b86af600000dc8'
# OSError: [Errno 16] Device or resource busy: '.nfs00000005a749554500000dcb'
# OSError: [Errno 16] Device or resource busy: '.nfs00000005a76944c600000dbd'
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 688, in _rmtree_safe_fd
#     os.unlink(entry.name, dir_fd=topfd)
# OSError: [Errno 16] Device or resource busy: '.nfs00000005a71fcc0700000db0'
# OSError: [Errno 16] Device or resource busy: '.nfs00000005a7524f1500000dba'
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 688, in _rmtree_safe_fd
#     os.unlink(entry.name, dir_fd=topfd)
# OSError: [Errno 16] Device or resource busy: '.nfs00000005a733e38900000dc5'
# OSError: [Errno 16] Device or resource busy: '.nfs00000005a733e38600000dc1'
# OSError: [Errno 16] Device or resource busy: '.nfs00000005a713f6aa00000dc9'
# OSError: [Errno 16] Device or resource busy: '.nfs00000005a760531000000db1'
# OSError: [Errno 16] Device or resource busy: '.nfs00000005a77e97f700000dc6'
# OSError: [Errno 16] Device or resource busy: '.nfs00000005a714760600000dce'
# OSError: [Errno 16] Device or resource busy: '.nfs00000005a7b11e0c00000dc4'
# OSError: [Errno 16] Device or resource busy: '.nfs00000005a710e47a00000dca'
# OSError: [Errno 16] Device or resource busy: '.nfs00000005a77e97f400000dc7'
# Embedding cells: 100%|██████████| 929/929 [03:21<00:00,  4.60it/s]
# /allen/programs/celltypes/workgroups/mousecelltypes/Rohan/code/scgpt/scGPT/scgpt/tasks/cell_emb.py:279: ImplicitModificationWarning: Setting element `.obsm['X_scGPT']` of view, initializing view as actual.
#   adata.obsm["X_scGPT"] = cell_embeddings

# %% [markdown]
# Embed the query dataset

# %%
test_embed_adata = scg.tasks.embed_data(
    adata_test,
    model_dir,
    gene_col=gene_col,
    batch_size=128,
)
# Out:
# scGPT - INFO - match 3388/4000 genes in vocabulary of size 60697.
# /allen/programs/celltypes/workgroups/mousecelltypes/Rohan/code/scgpt/scGPT/scgpt/model/model.py:77: UserWarning: flash-attn is not installed, using pytorch transformer instead. Set use_fast_transformer=False to avoid this warning. Installing flash-attn is highly recommended.
#   warnings.warn(
# Embedding cells: 100%|██████████| 1295/1295 [04:56<00:00,  4.58it/s]Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 300, in _run_finalizers
#     finalizer()
# Traceback (most recent call last):
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 300, in _run_finalizers
#     finalizer()
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 300, in _run_finalizers
#     finalizer()
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 300, in _run_finalizers
#     finalizer()
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 224, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 300, in _run_finalizers
#     finalizer()
# Traceback (most recent call last):
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 300, in _run_finalizers
#     finalizer()
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 224, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 224, in __call__
#     res = self._callback(*self._args, **self._kwargs)
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 224, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 133, in _remove_temp_dir
#     rmtree(tempdir)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 224, in __call__
#     res = self._callback(*self._args, **self._kwargs)
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 133, in _remove_temp_dir
#     rmtree(tempdir)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 300, in _run_finalizers
#     finalizer()
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 133, in _remove_temp_dir
#     rmtree(tempdir)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 734, in rmtree
#     _rmtree_safe_fd(fd, path, onerror)
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 224, in __call__
#     res = self._callback(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 133, in _remove_temp_dir
#     rmtree(tempdir)
# Traceback (most recent call last):
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 300, in _run_finalizers
#     finalizer()
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 300, in _run_finalizers
#     finalizer()
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 300, in _run_finalizers
#     finalizer()
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 734, in rmtree
#     _rmtree_safe_fd(fd, path, onerror)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 300, in _run_finalizers
#     finalizer()
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 734, in rmtree
#     _rmtree_safe_fd(fd, path, onerror)
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 133, in _remove_temp_dir
#     rmtree(tempdir)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 300, in _run_finalizers
#     finalizer()
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 300, in _run_finalizers
#     finalizer()
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 300, in _run_finalizers
#     finalizer()
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 224, in __call__
#     res = self._callback(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 734, in rmtree
#     _rmtree_safe_fd(fd, path, onerror)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 224, in __call__
#     res = self._callback(*self._args, **self._kwargs)
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 224, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 300, in _run_finalizers
#     finalizer()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 300, in _run_finalizers
#     finalizer()
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 224, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 690, in _rmtree_safe_fd
#     onerror(os.unlink, fullname, sys.exc_info())
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 300, in _run_finalizers
#     finalizer()
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 300, in _run_finalizers
#     finalizer()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 690, in _rmtree_safe_fd
#     onerror(os.unlink, fullname, sys.exc_info())
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 224, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 224, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 224, in __call__
#     res = self._callback(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 690, in _rmtree_safe_fd
#     onerror(os.unlink, fullname, sys.exc_info())
# Traceback (most recent call last):
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 734, in rmtree
#     _rmtree_safe_fd(fd, path, onerror)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 224, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 133, in _remove_temp_dir
#     rmtree(tempdir)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 133, in _remove_temp_dir
#     rmtree(tempdir)
# Traceback (most recent call last):
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 300, in _run_finalizers
#     finalizer()
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 690, in _rmtree_safe_fd
#     onerror(os.unlink, fullname, sys.exc_info())
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 133, in _remove_temp_dir
#     rmtree(tempdir)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 300, in _run_finalizers
#     finalizer()
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 300, in _run_finalizers
#     finalizer()
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 300, in _run_finalizers
#     finalizer()
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 133, in _remove_temp_dir
#     rmtree(tempdir)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 224, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 300, in _run_finalizers
#     finalizer()
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 688, in _rmtree_safe_fd
#     os.unlink(entry.name, dir_fd=topfd)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 224, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 133, in _remove_temp_dir
#     rmtree(tempdir)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 224, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 300, in _run_finalizers
#     finalizer()
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 224, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 300, in _run_finalizers
#     finalizer()
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 688, in _rmtree_safe_fd
#     os.unlink(entry.name, dir_fd=topfd)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 300, in _run_finalizers
#     finalizer()
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 133, in _remove_temp_dir
#     rmtree(tempdir)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 133, in _remove_temp_dir
#     rmtree(tempdir)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 133, in _remove_temp_dir
#     rmtree(tempdir)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 688, in _rmtree_safe_fd
#     os.unlink(entry.name, dir_fd=topfd)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 300, in _run_finalizers
#     finalizer()
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 300, in _run_finalizers
#     finalizer()
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 690, in _rmtree_safe_fd
#     onerror(os.unlink, fullname, sys.exc_info())
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 133, in _remove_temp_dir
#     rmtree(tempdir)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 734, in rmtree
#     _rmtree_safe_fd(fd, path, onerror)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 734, in rmtree
#     _rmtree_safe_fd(fd, path, onerror)
# Traceback (most recent call last):
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 224, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 300, in _run_finalizers
#     finalizer()
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 688, in _rmtree_safe_fd
#     os.unlink(entry.name, dir_fd=topfd)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 734, in rmtree
#     _rmtree_safe_fd(fd, path, onerror)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 224, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 224, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 734, in rmtree
#     _rmtree_safe_fd(fd, path, onerror)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 224, in __call__
#     res = self._callback(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 133, in _remove_temp_dir
#     rmtree(tempdir)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 133, in _remove_temp_dir
#     rmtree(tempdir)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 224, in __call__
#     res = self._callback(*self._args, **self._kwargs)
# OSError: [Errno 16] Device or resource busy: '.nfs00000005a794383100000dd2'
# Traceback (most recent call last):
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 734, in rmtree
#     _rmtree_safe_fd(fd, path, onerror)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 133, in _remove_temp_dir
#     rmtree(tempdir)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 133, in _remove_temp_dir
#     rmtree(tempdir)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 224, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 224, in __call__
#     res = self._callback(*self._args, **self._kwargs)
# OSError: [Errno 16] Device or resource busy: '.nfs00000005a76053b700000dd0'
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 734, in rmtree
#     _rmtree_safe_fd(fd, path, onerror)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 224, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 734, in rmtree
#     _rmtree_safe_fd(fd, path, onerror)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 734, in rmtree
#     _rmtree_safe_fd(fd, path, onerror)
# OSError: [Errno 16] Device or resource busy: '.nfs00000005a77b27cf00000dd8'
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 224, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 224, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 688, in _rmtree_safe_fd
#     os.unlink(entry.name, dir_fd=topfd)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 734, in rmtree
#     _rmtree_safe_fd(fd, path, onerror)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 690, in _rmtree_safe_fd
#     onerror(os.unlink, fullname, sys.exc_info())
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 690, in _rmtree_safe_fd
#     onerror(os.unlink, fullname, sys.exc_info())
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 133, in _remove_temp_dir
#     rmtree(tempdir)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 300, in _run_finalizers
#     finalizer()
# OSError: [Errno 16] Device or resource busy: '.nfs00000005a69cdf9d00000dd7'
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 133, in _remove_temp_dir
#     rmtree(tempdir)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 224, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 690, in _rmtree_safe_fd
#     onerror(os.unlink, fullname, sys.exc_info())
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 133, in _remove_temp_dir
#     rmtree(tempdir)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 690, in _rmtree_safe_fd
#     onerror(os.unlink, fullname, sys.exc_info())
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 133, in _remove_temp_dir
#     rmtree(tempdir)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 734, in rmtree
#     _rmtree_safe_fd(fd, path, onerror)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 300, in _run_finalizers
#     finalizer()
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 734, in rmtree
#     _rmtree_safe_fd(fd, path, onerror)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 133, in _remove_temp_dir
#     rmtree(tempdir)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 690, in _rmtree_safe_fd
#     onerror(os.unlink, fullname, sys.exc_info())
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 734, in rmtree
#     _rmtree_safe_fd(fd, path, onerror)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 300, in _run_finalizers
#     finalizer()
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 734, in rmtree
#     _rmtree_safe_fd(fd, path, onerror)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 133, in _remove_temp_dir
#     rmtree(tempdir)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 133, in _remove_temp_dir
#     rmtree(tempdir)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 133, in _remove_temp_dir
#     rmtree(tempdir)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 690, in _rmtree_safe_fd
#     onerror(os.unlink, fullname, sys.exc_info())
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 690, in _rmtree_safe_fd
#     onerror(os.unlink, fullname, sys.exc_info())
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 133, in _remove_temp_dir
#     rmtree(tempdir)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 133, in _remove_temp_dir
#     rmtree(tempdir)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 690, in _rmtree_safe_fd
#     onerror(os.unlink, fullname, sys.exc_info())
# OSError: [Errno 16] Device or resource busy: '.nfs00000005a7a16a3200000dd5'
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 690, in _rmtree_safe_fd
#     onerror(os.unlink, fullname, sys.exc_info())
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 688, in _rmtree_safe_fd
#     os.unlink(entry.name, dir_fd=topfd)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 688, in _rmtree_safe_fd
#     os.unlink(entry.name, dir_fd=topfd)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 224, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 734, in rmtree
#     _rmtree_safe_fd(fd, path, onerror)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 133, in _remove_temp_dir
#     rmtree(tempdir)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 734, in rmtree
#     _rmtree_safe_fd(fd, path, onerror)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 688, in _rmtree_safe_fd
#     os.unlink(entry.name, dir_fd=topfd)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 734, in rmtree
#     _rmtree_safe_fd(fd, path, onerror)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 734, in rmtree
#     _rmtree_safe_fd(fd, path, onerror)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 688, in _rmtree_safe_fd
#     os.unlink(entry.name, dir_fd=topfd)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 690, in _rmtree_safe_fd
#     onerror(os.unlink, fullname, sys.exc_info())
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 224, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 690, in _rmtree_safe_fd
#     onerror(os.unlink, fullname, sys.exc_info())
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 688, in _rmtree_safe_fd
#     os.unlink(entry.name, dir_fd=topfd)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 734, in rmtree
#     _rmtree_safe_fd(fd, path, onerror)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 690, in _rmtree_safe_fd
#     onerror(os.unlink, fullname, sys.exc_info())
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 690, in _rmtree_safe_fd
#     onerror(os.unlink, fullname, sys.exc_info())
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 224, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 734, in rmtree
#     _rmtree_safe_fd(fd, path, onerror)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 734, in rmtree
#     _rmtree_safe_fd(fd, path, onerror)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 734, in rmtree
#     _rmtree_safe_fd(fd, path, onerror)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 688, in _rmtree_safe_fd
#     os.unlink(entry.name, dir_fd=topfd)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 734, in rmtree
#     _rmtree_safe_fd(fd, path, onerror)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 688, in _rmtree_safe_fd
#     os.unlink(entry.name, dir_fd=topfd)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 734, in rmtree
#     _rmtree_safe_fd(fd, path, onerror)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 688, in _rmtree_safe_fd
#     os.unlink(entry.name, dir_fd=topfd)
# OSError: [Errno 16] Device or resource busy: '.nfs00000005a6accecf00000ddf'
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 688, in _rmtree_safe_fd
#     os.unlink(entry.name, dir_fd=topfd)
# OSError: [Errno 16] Device or resource busy: '.nfs00000005a710e4ee00000ddc'
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 690, in _rmtree_safe_fd
#     onerror(os.unlink, fullname, sys.exc_info())
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 734, in rmtree
#     _rmtree_safe_fd(fd, path, onerror)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 690, in _rmtree_safe_fd
#     onerror(os.unlink, fullname, sys.exc_info())
# OSError: [Errno 16] Device or resource busy: '.nfs00000005a72e2eeb00000de4'
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 690, in _rmtree_safe_fd
#     onerror(os.unlink, fullname, sys.exc_info())
# OSError: [Errno 16] Device or resource busy: '.nfs00000005a710e4ff00000de7'
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 133, in _remove_temp_dir
#     rmtree(tempdir)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 690, in _rmtree_safe_fd
#     onerror(os.unlink, fullname, sys.exc_info())
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 133, in _remove_temp_dir
#     rmtree(tempdir)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 688, in _rmtree_safe_fd
#     os.unlink(entry.name, dir_fd=topfd)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 688, in _rmtree_safe_fd
#     os.unlink(entry.name, dir_fd=topfd)
# OSError: [Errno 16] Device or resource busy: '.nfs00000005a74740ea00000ded'
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 688, in _rmtree_safe_fd
#     os.unlink(entry.name, dir_fd=topfd)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 688, in _rmtree_safe_fd
#     os.unlink(entry.name, dir_fd=topfd)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/multiprocessing/util.py", line 133, in _remove_temp_dir
#     rmtree(tempdir)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 690, in _rmtree_safe_fd
#     onerror(os.unlink, fullname, sys.exc_info())
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 690, in _rmtree_safe_fd
#     onerror(os.unlink, fullname, sys.exc_info())
# OSError: [Errno 16] Device or resource busy: '.nfs00000005a78b6f1400000de8'
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 690, in _rmtree_safe_fd
#     onerror(os.unlink, fullname, sys.exc_info())
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 690, in _rmtree_safe_fd
#     onerror(os.unlink, fullname, sys.exc_info())
# OSError: [Errno 16] Device or resource busy: '.nfs00000005a64fda5a00000dd3'
# OSError: [Errno 16] Device or resource busy: '.nfs00000005a7a16a3400000dd4'
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 688, in _rmtree_safe_fd
#     os.unlink(entry.name, dir_fd=topfd)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 690, in _rmtree_safe_fd
#     onerror(os.unlink, fullname, sys.exc_info())
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 688, in _rmtree_safe_fd
#     os.unlink(entry.name, dir_fd=topfd)
# OSError: [Errno 16] Device or resource busy: '.nfs00000005a7a9332b00000de6'
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 690, in _rmtree_safe_fd
#     onerror(os.unlink, fullname, sys.exc_info())
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 688, in _rmtree_safe_fd
#     os.unlink(entry.name, dir_fd=topfd)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 734, in rmtree
#     _rmtree_safe_fd(fd, path, onerror)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 734, in rmtree
#     _rmtree_safe_fd(fd, path, onerror)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 688, in _rmtree_safe_fd
#     os.unlink(entry.name, dir_fd=topfd)
# OSError: [Errno 16] Device or resource busy: '.nfs00000005a7a9333200000dd9'
# OSError: [Errno 16] Device or resource busy: '.nfs00000005a6accecd00000de1'
# OSError: [Errno 16] Device or resource busy: '.nfs00000005a6c8a42100000de2'
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 734, in rmtree
#     _rmtree_safe_fd(fd, path, onerror)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 688, in _rmtree_safe_fd
#     os.unlink(entry.name, dir_fd=topfd)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 688, in _rmtree_safe_fd
#     os.unlink(entry.name, dir_fd=topfd)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 690, in _rmtree_safe_fd
#     onerror(os.unlink, fullname, sys.exc_info())
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 688, in _rmtree_safe_fd
#     os.unlink(entry.name, dir_fd=topfd)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 688, in _rmtree_safe_fd
#     os.unlink(entry.name, dir_fd=topfd)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 688, in _rmtree_safe_fd
#     os.unlink(entry.name, dir_fd=topfd)
# OSError: [Errno 16] Device or resource busy: '.nfs00000005a790530000000dd6'
# OSError: [Errno 16] Device or resource busy: '.nfs00000005a77c21ed00000ddb'
# OSError: [Errno 16] Device or resource busy: '.nfs00000005a76a69b500000dea'
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 690, in _rmtree_safe_fd
#     onerror(os.unlink, fullname, sys.exc_info())
# OSError: [Errno 16] Device or resource busy: '.nfs00000005a6625ee900000dd1'
# OSError: [Errno 16] Device or resource busy: '.nfs00000005a700b90400000de0'
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 690, in _rmtree_safe_fd
#     onerror(os.unlink, fullname, sys.exc_info())
# OSError: [Errno 16] Device or resource busy: '.nfs00000005a76053c900000dec'
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 688, in _rmtree_safe_fd
#     os.unlink(entry.name, dir_fd=topfd)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 688, in _rmtree_safe_fd
#     os.unlink(entry.name, dir_fd=topfd)
# OSError: [Errno 16] Device or resource busy: '.nfs00000005a733e3ab00000de3'
# OSError: [Errno 16] Device or resource busy: '.nfs00000005a78a97e200000dee'
# OSError: [Errno 16] Device or resource busy: '.nfs00000005a790530500000def'
# OSError: [Errno 16] Device or resource busy: '.nfs00000005a791c1eb00000deb'
# OSError: [Errno 16] Device or resource busy: '.nfs00000005a774b84900000ddd'
# OSError: [Errno 16] Device or resource busy: '.nfs00000005a796479500000dda'
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 688, in _rmtree_safe_fd
#     os.unlink(entry.name, dir_fd=topfd)
# OSError: [Errno 16] Device or resource busy: '.nfs00000005a733e3b400000de9'
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 688, in _rmtree_safe_fd
#     os.unlink(entry.name, dir_fd=topfd)
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 690, in _rmtree_safe_fd
#     onerror(os.unlink, fullname, sys.exc_info())
# OSError: [Errno 16] Device or resource busy: '.nfs00000005a69cdf9b00000dde'
#   File "/allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/shutil.py", line 688, in _rmtree_safe_fd
#     os.unlink(entry.name, dir_fd=topfd)
# OSError: [Errno 16] Device or resource busy: '.nfs00000005a6c8a42d00000de5'
# Embedding cells: 100%|██████████| 1295/1295 [04:56<00:00,  4.36it/s]
# /allen/programs/celltypes/workgroups/mousecelltypes/Rohan/code/scgpt/scGPT/scgpt/tasks/cell_emb.py:279: ImplicitModificationWarning: Setting element `.obsm['X_scGPT']` of view, initializing view as actual.
#   adata.obsm["X_scGPT"] = cell_embeddings

# %% [markdown]
# Mark the reference vs. query cells and mask the cell types on query cells

# %%
# concatenate the two datasets
adata_concat = test_embed_adata.concatenate(ref_embed_adata, batch_key="dataset")
# mark the reference vs. query dataset
adata_concat.obs["is_ref"] = ["Query"] * len(test_embed_adata) + ["Reference"] * len(ref_embed_adata)
adata_concat.obs["is_ref"] = adata_concat.obs["is_ref"].astype("category")
# mask the query dataset cell types
adata_concat.obs[cell_type_key] = adata_concat.obs[cell_type_key].astype("category")
adata_concat.obs[cell_type_key] = adata_concat.obs[cell_type_key].cat.add_categories(["To be predicted"])
adata_concat.obs[cell_type_key][: len(test_embed_adata)] = "To be predicted"
# Out:
# /allen/scratch/aibstemp/rohang/.tmpdir/ipykernel_230924/4201321170.py:2: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adata_concat = test_embed_adata.concatenate(ref_embed_adata, batch_key="dataset")
# /allen/scratch/aibstemp/rohang/.tmpdir/ipykernel_230924/4201321170.py:11: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   adata_concat.obs[cell_type_key][: len(test_embed_adata)] = "To be predicted"

# %% [markdown]
# ## Visualize the embeddings

# %%
# sc.pp.neighbors(adata_concat, use_rep="X_scGPT")
# sc.tl.umap(adata_concat)
# sc.pl.umap(
#     adata_concat, color=["is_ref", cell_type_key], wspace=0.4, frameon=False, ncols=1
# )

# %% [markdown]
# ## Reference mapping and transfer the annotations

# %% [markdown]
# We run the reference mapping using cell-level majority voting. You may adjust the `k` parameter to control the number of nearest neighbors to consider for voting.

# %%
ref_cell_embeddings = ref_embed_adata.obsm["X_scGPT"]
test_emebd = test_embed_adata.obsm["X_scGPT"]

k = 10  # number of neighbors

# Build index
index = faiss.IndexFlatL2(ref_cell_embeddings.shape[1])
index.add(ref_cell_embeddings)

# Query dataset, k - number of closest elements (returns 2 numpy arrays)
distances, labels = index.search(test_emebd, k)

idx_list = [i for i in range(test_emebd.shape[0])]
preds = []
sim_list = distances

# %%
# building the index on top of the embeddings takes long - 27 minutes for ~1 800,000 cells. + 200,000 queries.
# annoy / scann are other fast knn classifier options for majority-vote based class label prediction.

# %%
for k in tqdm(idx_list):
    idx = labels[k]
    pred = ref_embed_adata.obs[cell_type_key].iloc[idx].value_counts()
    preds.append(pred.index[0])
gt = adata_test.obs[cell_type_key].to_numpy()
# Out:
# 100%|██████████| 165668/165668 [00:58<00:00, 2831.09it/s]

# %% [markdown]
# ## Evaluate the performance

# %%
res_dict = {
    "accuracy": np.round(accuracy_score(gt, preds), 3),
    "precision": np.round(precision_score(gt, preds, average="macro"), 3),
    "recall": np.round(recall_score(gt, preds, average="macro"), 3),
    "macro_f1": np.round(f1_score(gt, preds, average="macro"), 3),
}

rprint(res_dict)
# Out:
# {'accuracy': 0.701, 'precision': 0.583, 'recall': 0.683, 'macro_f1': 0.595}

# %% [markdown]
# Confusion matrix:

# %%
y_true = gt
y_pred = preds
cell_type_list = np.unique(y_true)
matrix = confusion_matrix(y_true, y_pred, labels=cell_type_list)
matrix = matrix.astype("float") / matrix.sum(axis=1)[:, np.newaxis]

df = pd.DataFrame(matrix, index=cell_type_list[: matrix.shape[0]], columns=cell_type_list[: matrix.shape[1]])

f, ax = plt.subplots(figsize=(12, 12))
sns.heatmap(
    df,
    cmap="Blues",
    annot=False,
    fmt=".2f",
    annot_kws={"size": 5},
    vmin=0,
    vmax=1,
    ax=ax,
    linewidths=0.1,
    square=True,
    cbar_kws={"shrink": 0.2},
    xticklabels=1,
    yticklabels=1,
)
# reduce font for xticklabels
plt.xticks(fontsize=4)
plt.yticks(fontsize=4)
plt.show()

# %%
# get classification report
from sklearn.metrics import classification_report

report = classification_report(y_true, y_pred, target_names=cell_type_list, output_dict=True)
df = pd.DataFrame(report).transpose()
display(df.tail(3))

# display full dataframe
pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)
pd.set_option("display.width", None)
pd.set_option("display.max_colwidth", None)

# reorder rows to match the order of celltypes
df = df.reindex(cell_type_list)


# color any values less than 0.5
def color_negative_red(val):
    color = "#ff9999" if val < 0.5 else "black"
    return "color: %s" % color


display(df.round(3).style.applymap(color_negative_red))
# Out:
#               precision    recall  f1-score        support
# accuracy       0.700678  0.700678  0.700678       0.700678
# macro avg      0.582590  0.682759  0.594599  165668.000000
# weighted avg   0.780676  0.700678  0.719702  165668.000000
# /allen/scratch/aibstemp/rohang/.tmpdir/ipykernel_230924/1970544275.py:22: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   display(df.round(3).style.applymap(color_negative_red))
# <style type="text/css">
# #T_e2471_row0_col0, #T_e2471_row0_col2, #T_e2471_row1_col1, #T_e2471_row3_col0, #T_e2471_row3_col2, #T_e2471_row4_col0, #T_e2471_row4_col1, #T_e2471_row4_col2, #T_e2471_row5_col0, #T_e2471_row5_col2, #T_e2471_row7_col0, #T_e2471_row8_col0, #T_e2471_row8_col1, #T_e2471_row8_col2, #T_e2471_row13_col0, #T_e2471_row15_col0, #T_e2471_row15_col2, #T_e2471_row19_col0, #T_e2471_row19_col2, #T_e2471_row20_col0, #T_e2471_row20_col2, #T_e2471_row23_col0, #T_e2471_row25_col0, #T_e2471_row31_col0, #T_e2471_row33_col1, #T_e2471_row34_col1, #T_e2471_row34_col2, #T_e2471_row35_col0, #T_e2471_row35_col2, #T_e2471_row36_col0, #T_e2471_row37_col0, #T_e2471_row37_col1, #T_e2471_row37_col2, #T_e2471_row40_col0, #T_e2471_row40_col2, #T_e2471_row41_col0, #T_e2471_row49_col0, #T_e2471_row49_col2, #T_e2471_row51_col0, #T_e2471_row51_col2, #T_e2471_row53_col0, #T_e2471_row53_col2, #T_e2471_row55_col0, #T_e2471_row55_col2, #T_e2471_row56_col0, #T_e2471_row56_col2, #T_e2471_row58_col0, #T_e2471_row58_col2, #T_e2471_row62_col1, #T_e2471_row62_col2, #T_e2471_row63_col0, #T_e2471_row63_col1, #T_e2471_row63_col2, #T_e2471_row65_col0, #T_e2471_row65_col1, #T_e2471_row65_col2, #T_e2471_row66_col0, #T_e2471_row66_col2, #T_e2471_row67_col0, #T_e2471_row67_col2, #T_e2471_row69_col1, #T_e2471_row70_col0, #T_e2471_row70_col2, #T_e2471_row71_col0, #T_e2471_row71_col2, #T_e2471_row74_col0, #T_e2471_row74_col2, #T_e2471_row75_col0, #T_e2471_row75_col2, #T_e2471_row82_col0, #T_e2471_row82_col2, #T_e2471_row83_col0, #T_e2471_row84_col0, #T_e2471_row84_col1, #T_e2471_row84_col2, #T_e2471_row85_col0, #T_e2471_row85_col1, #T_e2471_row85_col2, #T_e2471_row86_col0, #T_e2471_row86_col1, #T_e2471_row86_col2, #T_e2471_row87_col0, #T_e2471_row87_col2, #T_e2471_row90_col0, #T_e2471_row90_col1, #T_e2471_row90_col2, #T_e2471_row91_col0, #T_e2471_row91_col2, #T_e2471_row92_col0, #T_e2471_row92_col2, #T_e2471_row93_col0, #T_e2471_row94_col0, #T_e2471_row94_col1, #T_e2471_row94_col2, #T_e2471_row97_col1, #T_e2471_row97_col2, #T_e2471_row98_col0, #T_e2471_row98_col2, #T_e2471_row101_col0, #T_e2471_row105_col0, #T_e2471_row105_col2, #T_e2471_row108_col0, #T_e2471_row108_col2, #T_e2471_row109_col1, #T_e2471_row112_col0, #T_e2471_row112_col2, #T_e2471_row113_col0, #T_e2471_row113_col1, #T_e2471_row113_col2, #T_e2471_row114_col0, #T_e2471_row114_col2, #T_e2471_row115_col0, #T_e2471_row115_col2, #T_e2471_row116_col1, #T_e2471_row118_col0, #T_e2471_row120_col0, #T_e2471_row120_col1, #T_e2471_row120_col2, #T_e2471_row121_col1, #T_e2471_row126_col0, #T_e2471_row130_col0, #T_e2471_row133_col0 {
#   color: #ff9999;
# }
# #T_e2471_row0_col1, #T_e2471_row0_col3, #T_e2471_row1_col0, #T_e2471_row1_col2, #T_e2471_row1_col3, #T_e2471_row2_col0, #T_e2471_row2_col1, #T_e2471_row2_col2, #T_e2471_row2_col3, #T_e2471_row3_col1, #T_e2471_row3_col3, #T_e2471_row4_col3, #T_e2471_row5_col1, #T_e2471_row5_col3, #T_e2471_row6_col0, #T_e2471_row6_col1, #T_e2471_row6_col2, #T_e2471_row6_col3, #T_e2471_row7_col1, #T_e2471_row7_col2, #T_e2471_row7_col3, #T_e2471_row8_col3, #T_e2471_row9_col0, #T_e2471_row9_col1, #T_e2471_row9_col2, #T_e2471_row9_col3, #T_e2471_row10_col0, #T_e2471_row10_col1, #T_e2471_row10_col2, #T_e2471_row10_col3, #T_e2471_row11_col0, #T_e2471_row11_col1, #T_e2471_row11_col2, #T_e2471_row11_col3, #T_e2471_row12_col0, #T_e2471_row12_col1, #T_e2471_row12_col2, #T_e2471_row12_col3, #T_e2471_row13_col1, #T_e2471_row13_col2, #T_e2471_row13_col3, #T_e2471_row14_col0, #T_e2471_row14_col1, #T_e2471_row14_col2, #T_e2471_row14_col3, #T_e2471_row15_col1, #T_e2471_row15_col3, #T_e2471_row16_col0, #T_e2471_row16_col1, #T_e2471_row16_col2, #T_e2471_row16_col3, #T_e2471_row17_col0, #T_e2471_row17_col1, #T_e2471_row17_col2, #T_e2471_row17_col3, #T_e2471_row18_col0, #T_e2471_row18_col1, #T_e2471_row18_col2, #T_e2471_row18_col3, #T_e2471_row19_col1, #T_e2471_row19_col3, #T_e2471_row20_col1, #T_e2471_row20_col3, #T_e2471_row21_col0, #T_e2471_row21_col1, #T_e2471_row21_col2, #T_e2471_row21_col3, #T_e2471_row22_col0, #T_e2471_row22_col1, #T_e2471_row22_col2, #T_e2471_row22_col3, #T_e2471_row23_col1, #T_e2471_row23_col2, #T_e2471_row23_col3, #T_e2471_row24_col0, #T_e2471_row24_col1, #T_e2471_row24_col2, #T_e2471_row24_col3, #T_e2471_row25_col1, #T_e2471_row25_col2, #T_e2471_row25_col3, #T_e2471_row26_col0, #T_e2471_row26_col1, #T_e2471_row26_col2, #T_e2471_row26_col3, #T_e2471_row27_col0, #T_e2471_row27_col1, #T_e2471_row27_col2, #T_e2471_row27_col3, #T_e2471_row28_col0, #T_e2471_row28_col1, #T_e2471_row28_col2, #T_e2471_row28_col3, #T_e2471_row29_col0, #T_e2471_row29_col1, #T_e2471_row29_col2, #T_e2471_row29_col3, #T_e2471_row30_col0, #T_e2471_row30_col1, #T_e2471_row30_col2, #T_e2471_row30_col3, #T_e2471_row31_col1, #T_e2471_row31_col2, #T_e2471_row31_col3, #T_e2471_row32_col0, #T_e2471_row32_col1, #T_e2471_row32_col2, #T_e2471_row32_col3, #T_e2471_row33_col0, #T_e2471_row33_col2, #T_e2471_row33_col3, #T_e2471_row34_col0, #T_e2471_row34_col3, #T_e2471_row35_col1, #T_e2471_row35_col3, #T_e2471_row36_col1, #T_e2471_row36_col2, #T_e2471_row36_col3, #T_e2471_row37_col3, #T_e2471_row38_col0, #T_e2471_row38_col1, #T_e2471_row38_col2, #T_e2471_row38_col3, #T_e2471_row39_col0, #T_e2471_row39_col1, #T_e2471_row39_col2, #T_e2471_row39_col3, #T_e2471_row40_col1, #T_e2471_row40_col3, #T_e2471_row41_col1, #T_e2471_row41_col2, #T_e2471_row41_col3, #T_e2471_row42_col0, #T_e2471_row42_col1, #T_e2471_row42_col2, #T_e2471_row42_col3, #T_e2471_row43_col0, #T_e2471_row43_col1, #T_e2471_row43_col2, #T_e2471_row43_col3, #T_e2471_row44_col0, #T_e2471_row44_col1, #T_e2471_row44_col2, #T_e2471_row44_col3, #T_e2471_row45_col0, #T_e2471_row45_col1, #T_e2471_row45_col2, #T_e2471_row45_col3, #T_e2471_row46_col0, #T_e2471_row46_col1, #T_e2471_row46_col2, #T_e2471_row46_col3, #T_e2471_row47_col0, #T_e2471_row47_col1, #T_e2471_row47_col2, #T_e2471_row47_col3, #T_e2471_row48_col0, #T_e2471_row48_col1, #T_e2471_row48_col2, #T_e2471_row48_col3, #T_e2471_row49_col1, #T_e2471_row49_col3, #T_e2471_row50_col0, #T_e2471_row50_col1, #T_e2471_row50_col2, #T_e2471_row50_col3, #T_e2471_row51_col1, #T_e2471_row51_col3, #T_e2471_row52_col0, #T_e2471_row52_col1, #T_e2471_row52_col2, #T_e2471_row52_col3, #T_e2471_row53_col1, #T_e2471_row53_col3, #T_e2471_row54_col0, #T_e2471_row54_col1, #T_e2471_row54_col2, #T_e2471_row54_col3, #T_e2471_row55_col1, #T_e2471_row55_col3, #T_e2471_row56_col1, #T_e2471_row56_col3, #T_e2471_row57_col0, #T_e2471_row57_col1, #T_e2471_row57_col2, #T_e2471_row57_col3, #T_e2471_row58_col1, #T_e2471_row58_col3, #T_e2471_row59_col0, #T_e2471_row59_col1, #T_e2471_row59_col2, #T_e2471_row59_ ...

# %%
import pickle

save_dict = {
    "predictions": y_pred,
    "labels": y_true,
    "report": df,
}
with open(paths["data"] / "results/0_shot_ref_mapping_v1_donor_split.pkl", "wb") as f:
    pickle.dump(save_dict, f)
