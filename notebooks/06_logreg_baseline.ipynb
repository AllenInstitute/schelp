# %% [markdown]
# Classification with logistic regession on the balanced dataset.
#  - This is a baseline to assess performance of more complex models.
#  - Here here is no mitigation of batch effects; next iteration can consider a binning strategy.
#
# Overall, with 0.1% of the data and a couple of minutes of time to learn model parameters we achieve an accuracy of ~0.84.

# %%
import numpy as np
import anndata as ad
import scanpy as sc
from sklearn.model_selection import train_test_split
from schelp.utils.config import load_config
from rich import print as rprint
import pandas as pd


paths = load_config(dataset_key="init")

def load_dataset_balance(paths, seed=0):

    data_dir = str(paths["data"])
    adata_ = sc.read_h5ad(str(paths["data"]) + '/Human-Brain/balanced_SEAAD_MTG_RNAseq_Singleome_final-nuclei.2024-06-18.h5ad')
    adata_.obs["celltype"] = adata_.obs["Supertype"]
    adata_.obs["batch"] = adata_.obs["Donor ID"]

    num_types = adata_.obs["celltype"].unique().size
    id2type = dict(enumerate(adata_.obs["celltype"].cat.categories))
    celltypes = adata_.obs["celltype"].unique()
    celltype_id_labels = adata_.obs["celltype"].astype("category").cat.codes.values
    adata_.obs["celltype_id"] = celltype_id_labels
    adata_.obs["batch_id"] = adata_.obs["batch"].cat.codes.values
    adata_.var["gene_name"] = adata_.var.index.tolist()
    
    # get high variance genes
    sc.pp.highly_variable_genes(adata_, n_top_genes=4000, flavor="seurat_v3", batch_key="batch")
    adata_ = adata_[:, adata_.var["highly_variable"]]
    adata_ = sc.pp.subsample(adata_, fraction=0.1, copy=True, random_state=seed)
    n_cells = adata_.shape[0]

    # split the data into train and test
    train_ind, test_ind = train_test_split(range(n_cells), test_size=0.2, random_state=seed)
    adata = adata_[train_ind].to_memory()
    adata_test = adata_[test_ind].to_memory()
    
    del adata_
    print(f"There are {adata.shape[0]} cells in the reference set")
    print(f"There are {adata_test.shape[0]} cells in the query set")

    return adata, adata_test, celltypes, id2type

# %%
# get the data splits
adata, adata_test, celltypes, id2type = load_dataset_balance(paths=paths, seed=0)
# Out:
# /allen/programs/celltypes/workgroups/mousecelltypes/Rohan/env/miniconda3/envs/scgpt/lib/python3.9/site-packages/scanpy/preprocessing/_highly_variable_genes.py:72: UserWarning: `flavor='seurat_v3'` expects raw count data, but non-integers were found.
#   warnings.warn(
# There are 11120 cells in the reference set
# There are 2780 cells in the query set

# %%
# pipeline for logistic regression classifier
from sklearn.linear_model import LogisticRegression, LogisticRegressionCV
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.pipeline import Pipeline

# split the data into train and test
X_train = adata.X.A
y_train = adata.obs["celltype_id"]
X_test = adata_test.X.A
y_test = adata_test.obs["celltype_id"]

# create a pipeline
pipe = Pipeline([
    ("scaler", StandardScaler()),
    ("clf", LogisticRegressionCV(Cs=10, cv=5, max_iter=1000, n_jobs=-1))
])

# fit the pipeline
pipe.fit(X_train, y_train)

# predict the test set
y_pred = pipe.predict(X_test)

# print the accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f"Overall test accuracy: {accuracy:0.3f}")
# Out:
# Overall test accuracy: 0.840

# %%
#rprint(classification_report(y_test, y_pred, target_names=celltypes))
report = classification_report(y_test, y_pred, target_names=celltypes, output_dict=True)
df = pd.DataFrame(report).transpose()

# round entries to 3 decimal places
df = df.round(3)

# display full dataframe
pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)
pd.set_option("display.width", None)
pd.set_option("display.max_colwidth", None)

# reorder rows to match the order of celltypes
df = df.reindex(celltypes.categories.tolist())

# color any values less than 0.5
def color_negative_red(val):
    color = '#ff9999' if val < 0.5 else 'black'
    return 'color: %s' % color

display(df.round(3).style.applymap(color_negative_red))
# Out:
# /allen/scratch/aibstemp/rohang/.tmpdir/ipykernel_138499/4196266342.py:22: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   display(df.round(3).style.applymap(color_negative_red))
# <style type="text/css">
# #T_0ff30_row0_col0, #T_0ff30_row0_col1, #T_0ff30_row0_col2, #T_0ff30_row0_col3, #T_0ff30_row1_col0, #T_0ff30_row1_col1, #T_0ff30_row1_col2, #T_0ff30_row1_col3, #T_0ff30_row2_col0, #T_0ff30_row2_col1, #T_0ff30_row2_col2, #T_0ff30_row2_col3, #T_0ff30_row3_col0, #T_0ff30_row3_col1, #T_0ff30_row3_col2, #T_0ff30_row3_col3, #T_0ff30_row4_col0, #T_0ff30_row4_col1, #T_0ff30_row4_col2, #T_0ff30_row4_col3, #T_0ff30_row5_col0, #T_0ff30_row5_col1, #T_0ff30_row5_col2, #T_0ff30_row5_col3, #T_0ff30_row6_col0, #T_0ff30_row6_col1, #T_0ff30_row6_col2, #T_0ff30_row6_col3, #T_0ff30_row7_col0, #T_0ff30_row7_col1, #T_0ff30_row7_col2, #T_0ff30_row7_col3, #T_0ff30_row8_col0, #T_0ff30_row8_col1, #T_0ff30_row8_col2, #T_0ff30_row8_col3, #T_0ff30_row9_col0, #T_0ff30_row9_col1, #T_0ff30_row9_col2, #T_0ff30_row9_col3, #T_0ff30_row10_col0, #T_0ff30_row10_col1, #T_0ff30_row10_col2, #T_0ff30_row10_col3, #T_0ff30_row11_col0, #T_0ff30_row11_col1, #T_0ff30_row11_col2, #T_0ff30_row11_col3, #T_0ff30_row12_col0, #T_0ff30_row12_col1, #T_0ff30_row12_col2, #T_0ff30_row12_col3, #T_0ff30_row13_col0, #T_0ff30_row13_col1, #T_0ff30_row13_col2, #T_0ff30_row13_col3, #T_0ff30_row14_col0, #T_0ff30_row14_col1, #T_0ff30_row14_col2, #T_0ff30_row14_col3, #T_0ff30_row15_col0, #T_0ff30_row15_col1, #T_0ff30_row15_col2, #T_0ff30_row15_col3, #T_0ff30_row16_col0, #T_0ff30_row16_col1, #T_0ff30_row16_col2, #T_0ff30_row16_col3, #T_0ff30_row17_col0, #T_0ff30_row17_col1, #T_0ff30_row17_col2, #T_0ff30_row17_col3, #T_0ff30_row18_col0, #T_0ff30_row18_col1, #T_0ff30_row18_col2, #T_0ff30_row18_col3, #T_0ff30_row19_col0, #T_0ff30_row19_col1, #T_0ff30_row19_col2, #T_0ff30_row19_col3, #T_0ff30_row20_col0, #T_0ff30_row20_col1, #T_0ff30_row20_col2, #T_0ff30_row20_col3, #T_0ff30_row21_col0, #T_0ff30_row21_col1, #T_0ff30_row21_col2, #T_0ff30_row21_col3, #T_0ff30_row22_col0, #T_0ff30_row22_col1, #T_0ff30_row22_col2, #T_0ff30_row22_col3, #T_0ff30_row23_col0, #T_0ff30_row23_col1, #T_0ff30_row23_col2, #T_0ff30_row23_col3, #T_0ff30_row24_col0, #T_0ff30_row24_col1, #T_0ff30_row24_col2, #T_0ff30_row24_col3, #T_0ff30_row25_col0, #T_0ff30_row25_col1, #T_0ff30_row25_col2, #T_0ff30_row25_col3, #T_0ff30_row26_col0, #T_0ff30_row26_col1, #T_0ff30_row26_col2, #T_0ff30_row26_col3, #T_0ff30_row27_col0, #T_0ff30_row27_col1, #T_0ff30_row27_col2, #T_0ff30_row27_col3, #T_0ff30_row28_col0, #T_0ff30_row28_col1, #T_0ff30_row28_col2, #T_0ff30_row28_col3, #T_0ff30_row29_col0, #T_0ff30_row29_col1, #T_0ff30_row29_col2, #T_0ff30_row29_col3, #T_0ff30_row30_col0, #T_0ff30_row30_col1, #T_0ff30_row30_col2, #T_0ff30_row30_col3, #T_0ff30_row31_col0, #T_0ff30_row31_col1, #T_0ff30_row31_col2, #T_0ff30_row31_col3, #T_0ff30_row32_col0, #T_0ff30_row32_col1, #T_0ff30_row32_col2, #T_0ff30_row32_col3, #T_0ff30_row33_col0, #T_0ff30_row33_col1, #T_0ff30_row33_col2, #T_0ff30_row33_col3, #T_0ff30_row34_col0, #T_0ff30_row34_col1, #T_0ff30_row34_col2, #T_0ff30_row34_col3, #T_0ff30_row35_col0, #T_0ff30_row35_col1, #T_0ff30_row35_col2, #T_0ff30_row35_col3, #T_0ff30_row36_col0, #T_0ff30_row36_col1, #T_0ff30_row36_col2, #T_0ff30_row36_col3, #T_0ff30_row37_col0, #T_0ff30_row37_col1, #T_0ff30_row37_col2, #T_0ff30_row37_col3, #T_0ff30_row38_col0, #T_0ff30_row38_col1, #T_0ff30_row38_col2, #T_0ff30_row38_col3, #T_0ff30_row39_col0, #T_0ff30_row39_col1, #T_0ff30_row39_col2, #T_0ff30_row39_col3, #T_0ff30_row40_col0, #T_0ff30_row40_col1, #T_0ff30_row40_col2, #T_0ff30_row40_col3, #T_0ff30_row41_col0, #T_0ff30_row41_col1, #T_0ff30_row41_col2, #T_0ff30_row41_col3, #T_0ff30_row42_col0, #T_0ff30_row42_col1, #T_0ff30_row42_col2, #T_0ff30_row42_col3, #T_0ff30_row43_col0, #T_0ff30_row43_col1, #T_0ff30_row43_col2, #T_0ff30_row43_col3, #T_0ff30_row44_col0, #T_0ff30_row44_col1, #T_0ff30_row44_col2, #T_0ff30_row44_col3, #T_0ff30_row45_col0, #T_0ff30_row45_col1, #T_0ff30_row45_col2, #T_0ff30_row45_col3, #T_0ff30_row46_col0, #T_0ff30_row46_col1, #T_0ff30_row46_col2, #T_0ff30_row46_col3, #T_0ff30_row47_col0, #T_0ff30_row47_col1, #T_0ff30_row47_col2, #T_0ff30_row47_col3, #T_0ff30 ...
